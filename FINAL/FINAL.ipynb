# %% [markdown]
# ### Combining Data
# *In this project we will be combining information from a number of SQL tables, then displaying the information in a pandas DataFrame.

# %%
# %matplotlib inline
# bring in NumPy and pandas
import pandas as pd
import numpy as np
import requests
import matplotlib as mpl
import matplotlib.pyplot as plt

sns.set(style="whitegrid", color_codes=True)
df = pd.read_csv('./csv/Consumer_Complaints.csv')
df
# Out:
#        Date received                  Product  \
# 0         03/12/2014                 Mortgage
# 1         10/01/2016         Credit reporting
# 2         10/17/2016            Consumer Loan
# 3         06/08/2014              Credit card
# 4         09/13/2014          Debt collection
# 5         11/13/2013                 Mortgage
# 6         06/16/2015          Debt collection
# 7         06/15/2015         Credit reporting
# 8         11/13/2015                 Mortgage
# 9         10/21/2014                 Mortgage
# 10        04/14/2017                 Mortgage
# 11        03/30/2012             Student loan
# 12        02/03/2016          Debt collection
# 13        01/07/2015         Credit reporting
# 14        03/15/2013              Credit card
# 15        07/18/2016         Credit reporting
# 16        02/17/2016          Debt collection
# 17        11/07/2014                 Mortgage
# 18        04/17/2015                 Mortgage
# ...

# %% [markdown]
# ### Display companies by the amount of complaints they have received

# %%
groupedByName = df.groupby('Company')
groupedByName.size().sort_values(ascending=False)
# Out:
# Company
# EQUIFAX, INC.                                   70565
# BANK OF AMERICA, NATIONAL ASSOCIATION           70541
# Experian Information Solutions Inc.             59502
# WELLS FARGO & COMPANY                           58509
# TRANSUNION INTERMEDIATE HOLDINGS, INC.          53727
# JPMORGAN CHASE & CO.                            47353
# CITIBANK, N.A.                                  38474
# OCWEN LOAN SERVICING LLC                        25485
# CAPITAL ONE FINANCIAL CORPORATION               23470
# Navient Solutions, LLC.                         21866
# NATIONSTAR MORTGAGE                             17542
# SYNCHRONY FINANCIAL                             15136
# U.S. BANCORP                                    13662
# Ditech Financial LLC                            12345
# AMERICAN EXPRESS COMPANY                         9581
# PNC Bank N.A.                                    9461
# ENCORE CAPITAL GROUP INC.                        8747
# ...

# %%
response = df.groupby('Company response to consumer')
response.size().sort_values(ascending=False).plot.bar()

# %% [markdown]
# *as we can see from the graph above, the majority of the complaints are closed with explanation*

# %%
state = df.groupby('State')
state.size().sort_values(ascending=False).plot(kind='bar',figsize=(12, 10))

# %% [markdown]
# From this statistic we can see that California, Florida, Texas and New York are the states that receive the most amount of complaints.

# %% [markdown]
# ### Conclusion
# Overall we can conclude that the biggest and most populated states receive the most amount of complaint. The good part is that about 90% of the complaints are being addressed and investigated.

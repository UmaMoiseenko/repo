# %% [markdown]
# #### 1. Load mushroom data from the web into a pandas dataframe.

# %%
# %matplotlib inline
# bring in NumPy and pandas
import pandas as pd
import numpy as np
import requests
import matplotlib as mpl
import matplotlib.pyplot as plt

url="https://archive.ics.uci.edu/ml/machine-learning-databases/mushroom/agaricus-lepiota.data"
s = requests.get(url).content
s = s.decode('utf-8')
s_rows = s.split('\n')
s_rows_cols = [each.split() for each in s_rows]
tempDf = pd.DataFrame(s_rows_cols)
tempDf = tempDf[0].str.split(',', expand=True)

# %% [markdown]
# #### 2. Create a new table.
# Create a dataframe that consists of 3 named columns, and replace given codes with numeric values.

# %%
df = pd.concat([tempDf[0], tempDf[5], tempDf[22]], axis=1, keys=['Edible', 'Odor', 'Habitat'])

df['Edible'] = df['Edible'].replace(['p', 'e'], [1, 2])

df['Odor'] = df['Odor'].replace(
    ['a', 'l', 'c', 'y', 'f', 'm', 'n', 'p', 's'], 
    [1, 2, 3, 4, 5, 6, 7, 8, 9])

df['Habitat'] = df['Habitat'].replace(
    ['g', 'l', 'm', 'p', 'u', 'w', 'd'],
    [1, 2, 3, 4, 5, 6, 7])


pd.options.display.float_format = '{:,.0f}'.format
df
# Out:
#       Edible  Odor  Habitat
# 0          1     8        5
# 1          2     1        1
# 2          2     2        3
# 3          1     8        5
# 4          2     7        1
# 5          2     1        1
# 6          2     1        3
# 7          2     2        3
# 8          1     8        1
# 9          2     1        3
# 10         2     2        1
# 11         2     1        3
# 12         2     1        1
# 13         1     8        5
# 14         2     7        1
# 15         2     7        5
# 16         2     7        1
# 17         1     8        1
# 18         1     8        5
# 19         1     8        5
# 20         2     1        3
# 21         1     8        1
# 22         2     2        3
# 23         2     1        3
# 24         2     2        3
# 25         1     8        1
# 26         2     1        3
# 27         2     2        3
# 28         2     7        5
# 29         2     1        7
# ...      ...   ...      ...
# 8095       1     6        7
# 8096       2     7        1
# 8097       1     9        2
# 8098       1     4        7
# 8099       2     7        1
# 8100       2     7        2
# 8101       1     9        4
# 8102       2     7        2
# 8103       2     7        2
# 8104       2     7        2
# 8105       2     7        2
# 8106       2     7        2
# 8107       2     7        2
# 8108       1     4        2
# 8109       2     7        1
# 8110       2     7        2
# 8111       2     7        1
# 8112       2     7        2
# 8113       1     4        7
# 8114       1     6        7
# 8115       2     7        2
# 8116       1     9        2
# 8117       1     4        7
# 8118       1     5        7
# 8119       2     7        2
# 8120       2     7        2
# 8121       2     7        2
# 8122       1     4        2
# 8123       2     7        2
# 8124     nan   nan      nan
#
# [8125 rows x 3 columns]

# %%
df.plot(kind='scatter', x='Edible', y='Odor')

# %% [markdown]
# Based on this plot, we can conclude that it's the poisonous mushromms that have range of different odors.

# %%
df.plot(kind='scatter', x='Edible', y='Habitat')

# %% [markdown]
# From looking at ascattaerplot for edible / poisonous mushrooms and  where they grow, we can conclude that both can be find in variety of different places.

# %% [markdown]
# #### Load articles data from TImes API using api-key.

# %%
import numpy as np
import pandas as pd
import json
import requests
from pandas.io.json import json_normalize

url = 'https://api.nytimes.com/svc/search/v2/articlesearch.json'`
response = requests.get(url, params={'api-key': '92578513a207431fa77e1bed363891ad'});
data = json.loads(response.content)
df = json_normalize(data['response']['docs'])
# Out:
#                         _id          byline.original document_type  \
# 0  5a122f977c459f246b636349  By THE ASSOCIATED PRESS       article
# 1  5a122f817c459f246b636348          By JESS BIDGOOD       article
# 2  5a122edf7c459f246b636347  By THE ASSOCIATED PRESS       article
# 3  5a122e1f7c459f246b636346               By REUTERS       article
# 4  5a122dbf7c459f246b636345        By CLYDE HABERMAN       article
# 5  5a122cb67c459f246b636344               By REUTERS       article
# 6  5a122be07c459f246b636343                     None       article
# 7  5a122b5b7c459f246b636342  By THE ASSOCIATED PRESS       article
# 8  5a122b5a7c459f246b636341  By THE ASSOCIATED PRESS       article
# 9  5a122aa87c459f246b636340  By THE ASSOCIATED PRESS       article
#
#   headline.kicker                                      headline.main  \
# 0             NaN  Toddler Pulled From Pond in a Florida Developm...
# 1             NaN  In Race Against Roy Moore, Democratic Candidat...
# 2             NaN  The Latest: Kelly Clarkson, Pink Open American...
# 3             NaN  Factbox-Where Chile's Presidential Candidates ...
# 4    Retro Report  Questioning Evolution: The Push to Change Scie...
# 5             NaN  'Transparent' Star Jeffrey Tambor Says He May ...
# 6             NaN                  No Corrections: November 20, 2017
# 7             NaN       Dolphins QB Jay Cutler Suffered a Concussion
# 8             NaN  The Latest: Trump Voices Doubt About Trophy Hu...
# 9             NaN  Senator Al Franken Cut From PBS David Letterma...
#
#                              headline.print_headline  \
# 0  Toddler Pulled From Pond in a Florida Developm...
# 1
# 2  The Latest: Kelly Clarkson, Pink Open American...
# 3  Factbox-Where Chile's Presidential Candidates ...
# 4  Evolving Tactics Helping Creationists Put Scie...
# 5  'Transparent' Star Jeffrey Tambor Says He May ...
# 6                                        Corrections
# 7       Dolphins QB Jay Cutler Suffered a Concussion
# 8  The Latest: Trump Voices Doubt About Trophy Hu...
# 9  Senator Al Franken Cut From PBS David Letterma...
#
#                                             keywords  \
# 0                                                 []
# 1  [{'isMajor': 'N', 'rank': 1, 'name': 'subject'...
# 2                                                 []
# 3                                                 []
# 4  [{'isMajor': 'N', 'rank': 1, 'name': 'subject'...
# 5                                                 []
# 6                                                 []
# 7                                                 []
# 8                                                 []
# 9                                                 []
#
#                                           multimedia     new_desk  \
# 0                                                 []         None
# 1                                                 []     National
# 2                                                 []         None
# 3                                                 []         None
# 4  [{'type': 'image', 'subtype': 'xlarge', 'url':...     National
# 5                                                 []         None
# 6                                                 []  Corrections
# 7                                                 []         None
# 8                                                 []         None
# 9                                                 []         None
#
#                    pub_date  score  section_name  \
# 0  2017-11-20T01:27:38+0000    1.0           NaN
# 1  2017-11-20T01:27:18+0000    1.0           NaN
# 2  2017-11-20T01:24:37+0000    1.0           NaN
# 3  2017-11-20T01:21:27+0000    1.0      Americas
# 4  2017-11-20T01:19:47+0000    1.0           NaN
# 5  2017-11-20T01:15:27+0000    1.0           NaN
# 6  2017-11-20T01:11:49+0000    1.0           NaN
# 7  2017-11-20T01:09:40+0000    1.0  Pro Football
# 8  2017-11-20T01:09:38+0000    1.0      Politics
# 9  2017-11-20T01:06:37+0000    1.0           NaN
#
#                                              snippet              source  \
# 0  The Palm Beach County Sheriff's Office says a ...                  AP
# 1  Alabama Democrats see a rare chance of victory...  The New York Times
# 2                   The Latest on (all times local):                  AP
# 3  Conservative billionaire Sebastian Pinera and ...             Reuters
# 4  Legislation and lawsuits that reject scientifi...  The New York Times
# 5  Jeffrey Tambor, the Emmy-winning star of the A...             Reuters
# 6  Corrections appearing in print on Monday, Nove...  The New York Times
# 7   Jay Cutler is all too familiar with concussions.                  AP
# 8  The Latest on President Donald Trump's tweets ...                  AP
# 9  PBS and WETA say Minnesota U.S. Senator Al Fra...                  AP
#
#   type_of_material                                                uri  \
# 0             News  nyt://article/7c2d0e80-d1d5-5463-aa53-c1b0af63...
# 1             News  nyt://article/1cc0c0ae-ca11-5da7-9292-786e64ef...
# 2             News  nyt://article/55cd624c-f05c-5425-b83a-e0c30f42...
# 3             News  nyt://article/d05f113e-392d-5bb9-8637-189ce044...
# 4             News  nyt://article/9a14ac2d-05f0-5795-8155-412f36d3...
# 5             News  nyt://article/2c58e14c-409e-5c9e-b9be-bb4ba8cd...
# 6       Correction  nyt://article/60d51c85-9e0c-5691-bd9d-2d99df9e...
# 7             News  nyt://article/e102d08a-f52d-51f8-9e85-bf1cea3f...
# 8             News  nyt://article/6088771b-d9eb-5625-9009-f860a454...
# 9             News  nyt://article/ffa83417-7a4e-55a6-b76d-e8899080...
#
#                                              web_url  word_count
# 0  https://www.nytimes.com/aponline/2017/11/19/us...         109
# 1  https://www.nytimes.com/2017/11/19/us/jones-al...        1326
# 2  https://www.nytimes.com/aponline/2017/11/19/us...         226
# 3  https://www.nytimes.com/reuters/2017/11/19/wor...         442
# 4  https://www.nytimes.com/2017/11/19/us/retro-re...        1029
# 5  https://www.nytimes.com/reuters/2017/11/19/art...         532
# 6  https://www.nytimes.com/2017/11/19/pageoneplus...          73
# 7  https://www.nytimes.com/aponline/2017/11/19/sp...         546
# 8  https://www.nytimes.com/aponline/2017/11/19/us...         296
# 9  https://www.nytimes.com/aponline/2017/11/19/us...         115
